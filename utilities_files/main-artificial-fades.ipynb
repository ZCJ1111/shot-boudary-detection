# %%
#import torch
#from torchvision import transforms
#from torch.utils.data import Dataset, DataLoader
import numpy as np
from PIL import Image
from glob import glob
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
#import torch.nn as nn
#import torch.nn.functional as F
from tqdm import tqdm
import os 
from sklearn.metrics import confusion_matrix
from scipy.stats import logistic
import imageio
from videoio import videosave, videoread
from moviepy.editor import *

import json
import matplotlib.pyplot as plt
import cv2 as cv
import numpy as np
import pylab
import imageio
from tqdm import tqdm
from joblib import Parallel, delayed
from videoio import videosave, videoread
import os
from moviepy.editor import *
import os
from natsort import natsorted
from glob import glob

# %%
import fadesUtilities as fades_util

# %%
#filename = "9210f99e-da25-41ed-9930-433a24105445_preview.mp4"
hist_eq0 = False
cleanup = False

if hist_eq0:
    output_path0 = 'results_MR_hist_eq'
else:
    output_path0 = 'results_MR'
    
start_frame = 0
end_frame = 5500

'''
filename = "Esvz97epfh4Tk3uc0QM0tw__.mp4"
output_path0 = 'results_China2'

filename = "2163923509.mp4"
output_path0 = 'results_China'
'''

filename = "4657828609.mp4"
output_path0 = 'results_China3_rgb'


'''
filename = "transition_vid_fused_200.mp4"
output_path0 = 'results_trans_200_rgb'

filename = "/ml_data_fuse/" 
output_path0 = 'results_MR_hist_eq_test_vid_orig'
'''

filename = "/ml_data_fuse/cookup/The_Cook_Up_S01E36_ryffcopy.mp4" 
output_path0 = 'results_MR_hist_eq_test_vid_orig_rgb'

if not os.path.exists(output_path0):
    os.mkdir(output_path0)

# %%
fades_obj = fades_util.detectFades(filename, output_path0, start_frame, end_frame, rgb=True)

# %%
fades_obj.runHistogramOverlapCalc(INTERVAL = 100)

# %%
frames_identified = fades_obj.groupJSONsIdentifyTransitions(thold=0.90, display_transitions=False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5867/5867 [00:10<00:00, 547.26it/s]
# 68

# %%
np.sort(np.array(frames_identified))
# Out:
# array([ 249,  623,  648,  673,  698,  699,  749,  777,  815,  821,  827,
#         833,  862,  885,  906,  920,  940,  971,  995, 1026, 1052, 1078,
#        1100, 1172, 1590, 1655, 1801, 1878, 1966, 2076, 2209, 2290, 2528,
#        2631, 2667, 2705, 2850, 2888, 3171, 3219, 3314, 3354, 3408, 3515,
#        3884, 3996, 4040, 4151, 4700, 4765, 4842, 4897, 4950, 5059, 5144,
#        5190, 5342, 5407, 5447, 5503, 5550, 5631, 5731, 5904, 5939, 6005,
#        6306, 6406])

# %%
#fades_obj.writeTransitionFrames(hist_eq0)
# Out:
# True
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# (1080, 1920, 3)
# ...

# %%
'''
#prev1, next1 = fades_obj.calculateHistogramOverlapSingle(5484)

plt.imshow(prev1,vmin=0,vmax=255,cmap='gray')
plt.show()

plt.imshow(next1,vmin=0,vmax=255,cmap='gray')
plt.show()

prev_img = prev1
next_img = next1

n, m = prev_img.shape
N = n*m

bins = 10
h1 = np.histogram(prev_img.flatten(), bins=np.arange(0,255.1,255/bins))[0]/N
h2 = np.histogram(next_img.flatten(), bins=np.arange(0,255.1,255/bins))[0]/N

bins = np.ones((len(h1),1))

sm = 0
for i in range(len(bins)):
    sm += np.minimum(bins[i]*h1[i], bins[i]*h2[i])

print(sm)
'''
