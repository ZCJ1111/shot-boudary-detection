# %%
import imageio
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
L = []
for frame in tqdm(range(3980, 4026)):
    vid0 = imageio.get_reader('wpt_test.mp4',  'ffmpeg')
    img = L.append(vid0.get_data(frame))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 46/46 [01:02<00:00,  1.36s/it]

# %%
import numpy as np
vid = np.stack(L,0)

# %%
np.save("wpt_table.npy",vid)

# %%
import cv2 as cv

L = []
for k in range(36):
    
    if k<10:
        kk='0'+str(k)
    else:
        kk = str(k)
        
    path = '/ml_data_fuse/datasets/fade_boundaries/0/'+str(kk)+'.png'
    
    img = cv.imread(path)
    L.append(img)
    
vid = np.stack(L,0)

# %%
vid.shape
# Out:
# (36, 108, 192, 3)

# %%
from videoio import videosave
videosave("adam_test.mp4", vid/255)

# %%
vid.shape
# Out:
# (36, 108, 192, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(vid[-1,:,:,:])

# %%
kk
# Out:
# '09'
